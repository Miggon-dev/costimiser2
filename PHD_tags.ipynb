# %%
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize":(12, 4)})
sns.set_style('whitegrid')
sns.set_context('notebook')

# %%
with open("wedge_vars.txt", "rb") as f:
    raw = f.read(2000)
 
print(raw[:1000])
# Out:
# b'Time\t2-003-UZ001    Presse :  Istwert Geschwindigkeit\t2-003-UZ001    Speedsizer :  Istwert Geschwindigkeit\t2-033-FC100    St\xc3\xa4rke Arbeitsbeh\xc3\xa4lter 1 :  Ausgang\t2-033-FC100    St\xc3\xa4rke Arbeitsbeh\xc3\xa4lter 1 :  Messwert\t2-033-FC150    St\xc3\xa4rke Speedsizer 1 :  Ausgang\t2-033-FC150    St\xc3\xa4rke Speedsizer 1 :  Messwert\t2-033-FC200    St\xc3\xa4rke Arbeitsbeh\xc3\xa4lter 2 :  Ausgang\t2-033-FC200    St\xc3\xa4rke Arbeitsbeh\xc3\xa4lter 2 :  Messwert\t2-033-FC250    St\xc3\xa4rke Speedsizer 2 :  Ausgang\t2-033-FC250    St\xc3\xa4rke Speedsizer 2 :  Messwert\t2-033-FI100    Konz. ST\xc3\xa4rke AB1 :  Messwert\t2-033-FI100-D2    Staerkeauftrag BW :  MESSWERT in [ml/m\xc2\xb2]\t2-033-FI200    Konz. ST\xc3\xa4rke AB2 :  Messwert\t2-033-PD110    Diff.Druck Filter 1 AB1 :  Messwert\t2-033-PD210    Diff.Druck Filter 1 AB2 :  Messwert\t2-033-PI045    Druck Rakelklemmschlauch FW :  Messwert\t2-033-PI055    Druck Rakelklemmschlauch BW :  Messwert\t2-033-PI110    Einlauf Filter 1 AB1 :  Messwert\t2-033-PI150    St\xc3\xa4rke Speedsizer 1 :  Messwert\t2-033-PI210    Einlauf Filter 1'

# %%
path = "wedge_vars.txt"
 
with open(path, "rb") as f:
    raw = f.read(4000)
 
print("First 120 bytes:", raw[:120])
print("\n-----\nAs UTF-8 (replace errors):\n-----")
print(raw.decode("utf-8", errors="replace")[:800])
print("\n-----\nAs CP1252 (replace errors):\n-----")
print(raw.decode("cp1252", errors="replace")[:800])
# Out:
# First 120 bytes: b'Time\t2-003-UZ001    Presse :  Istwert Geschwindigkeit\t2-003-UZ001    Speedsizer :  Istwert Geschwindigkeit\t2-033-FC100  '
#
# -----
# As UTF-8 (replace errors):
# -----
# Time	2-003-UZ001    Presse :  Istwert Geschwindigkeit	2-003-UZ001    Speedsizer :  Istwert Geschwindigkeit	2-033-FC100    Stärke Arbeitsbehälter 1 :  Ausgang	2-033-FC100    Stärke Arbeitsbehälter 1 :  Messwert	2-033-FC150    Stärke Speedsizer 1 :  Ausgang	2-033-FC150    Stärke Speedsizer 1 :  Messwert	2-033-FC200    Stärke Arbeitsbehälter 2 :  Ausgang	2-033-FC200    Stärke Arbeitsbehälter 2 :  Messwert	2-033-FC250    Stärke Speedsizer 2 :  Ausgang	2-033-FC250    Stärke Speedsizer 2 :  Messwert	2-033-FI100    Konz. STärke AB1 :  Messwert	2-033-FI100-D2    Staerkeauftrag BW :  MESSWERT in [ml/m²]	2-033-FI200    Konz. STärke AB2 :  Messwert	2-033-PD110    Diff.Druck Filter 1 AB1 :  Messwert	2-033-PD210    Diff.Druck Filter 1 AB2 :  Messwert	2-033-PI045    Druck Rakelklemmschlauch FW :  Messwe
#
# -----
# As CP1252 (replace errors):
# -----
# Time	2-003-UZ001    Presse :  Istwert Geschwindigkeit	2-003-UZ001    Speedsizer :  Istwert Geschwindigkeit	2-033-FC100    StÃ¤rke ArbeitsbehÃ¤lter 1 :  Ausgang	2-033-FC100    StÃ¤rke ArbeitsbehÃ¤lter 1 :  Messwert	2-033-FC150    StÃ¤rke Speedsizer 1 :  Ausgang	2-033-FC150    StÃ¤rke Speedsizer 1 :  Messwert	2-033-FC200    StÃ¤rke ArbeitsbehÃ¤lter 2 :  Ausgang	2-033-FC200    StÃ¤rke ArbeitsbehÃ¤lter 2 :  Messwert	2-033-FC250    StÃ¤rke Speedsizer 2 :  Ausgang	2-033-FC250    StÃ¤rke Speedsizer 2 :  Messwert	2-033-FI100    Konz. STÃ¤rke AB1 :  Messwert	2-033-FI100-D2    Staerkeauftrag BW :  MESSWERT in [ml/mÂ²]	2-033-FI200    Konz. STÃ¤rke AB2 :  Messwert	2-033-PD110    Diff.Druck Filter 1 AB1 :  Messwert	2-033-PD210    Diff.Druck Filter 1 AB2 :  Messwert	2-033-PI045    Druck Rakelklemmschlau

# %%
with open(path, "r", encoding="utf-8", errors="strict") as f:
    for i in range(1, 6):
        line = f.readline()
        print(f"LINE {i}: {repr(line[:250])}")
# Out:
# LINE 1: 'Time\t2-003-UZ001    Presse :  Istwert Geschwindigkeit\t2-003-UZ001    Speedsizer :  Istwert Geschwindigkeit\t2-033-FC100    Stärke Arbeitsbehälter 1 :  Ausgang\t2-033-FC100    Stärke Arbeitsbehälter 1 :  Messwert\t2-033-FC150    Stärke Speedsizer 1 :  Au'
# LINE 2: '\tAbplatzer Erkennung RSM 2 Mikrofon 1 [0..160 dB] \tAbplatzer Erkennung RSM 2 Mikrofon 2 [0..160 dB] \tAbplatzer Erkennung RSM 2 Mikrofon 3 [0..160 dB] \tAbplatzer Erkennung RSM 2 Mikrofon 4 [0..160 dB] \tAbplatzer Mikrofon FS Jagenberg [-1..0 ] (0 = fal'
# LINE 3: '\tArbeitsstation 1 : Aktuelle Drehzahl     [0..100 %]\tArbeitsstation 2 : Aktuelle Drehzahl     [0..100 %]\tAschemessung HC-Linie [0..10 g/l] \tAufschlämmb. 2 Wasserdurchfluss : REGLERAUSGANG     [0..100 \tAufschlämmb. 2 Wasserdurchfluss : SETPOINT TO CON'
# LINE 4: '\tNiveau B55 [-10..110 %] \tNiveau B801 : REGLERAUSGANG      [0..100 %]\tNiveau B801 : REGLERAUSGANG      [0..100 %]~^0\tNiveau B801 : SETPOINT TO CONTROLLER    [0..100 %]\tNiveau B801 : SETPOINT TO CONTROLLER    [0..100 %]~^0\tNiveau B801 [-10..110 %] \tNi'
# LINE 5: '  \tM/MIN\tM/MIN\t%\tM3/HR\t%\tM3/HR\t%\tM3/HR\t%\tM3/HR\tM3/HR\t\tM3/HR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\t%\tC\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\t%\t%\tG/KG\t%\tPa\t%\tPa\t%\tPa\t%\tPa\t%\tPa\t%\tPa\t%\t%\t%\tC\tC\t%\tC\tC\t%\tC\tC\t%\tC\tC\t%\tC\tC\t%\tC\tC\tM/MIN\tM/MIN\tM/MIN\tKN\tKN\t%\tKN/M\t%\tKN/M\tDEG\tDEG\tD'

# %%
# Read first 5 lines (4 name rows + 1 units row) as raw strings
hdr = pd.read_csv(path, sep="\t", header=None, nrows=5, encoding="utf-8", engine="python")
print("Header shape:", hdr.shape)
 
# Combine name rows 1-4 into one column name per field
names = hdr.iloc[0].fillna("").astype(str)
for r in [1, 2, 3]:
    names = names + hdr.iloc[r].fillna("").astype(str)
 
# Clean up
names = (names
         .str.replace(r"\s+", " ", regex=True)
         .str.strip())
 
# Make the first column name sane (it should be Time)
if names.iloc[0] == "":
    names.iloc[0] = "Time"
 
print("\nFirst 10 combined column names:")
print(names.head(10).to_list())
 
# Now read a small sample of the actual data (skip the 5 header lines)
df_sample = pd.read_csv(
    path,
    sep="\t",
    header=None,
    names=names,
    skiprows=5,
    nrows=5,
    encoding="utf-8",
    engine="python"
)
 
print("\nSample data:")
print(df_sample.head())
print("\nDtypes:")
print(df_sample.dtypes.head(10))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Read first 5 lines (4 name rows + 1 units row) as raw strings
# ----> 2 hdr = pd.read_csv(path, sep="\t", header=None, nrows=5, encoding="utf-8", engine="python")
#       3 print("Header shape:", hdr.shape)
#       5 # Combine name rows 1-4 into one column name per field
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:288, in PythonParser.read(self, rows)
#     285     indexnamerow = content[0]
#     286     content = content[1:]
# --> 288 alldata = self._rows_to_cols(content)
#     289 data, columns = self._exclude_implicit_index(alldata)
#     291 conv_data = self._convert_data(data)
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:1063, in PythonParser._rows_to_cols(self, content)
#    1057             reason = (
#    1058                 "Error could possibly be due to quotes being "
#    1059                 "ignored when a multi-char delimiter is used."
#    1060             )
#    1061             msg += ". " + reason
# -> 1063         self._alert_malformed(msg, row_num + 1)
#    1065 # see gh-13320
#    1066 zipped_content = list(lib.to_object_array(content, min_width=col_len).T)
#
# File c:\workspace\costimiser\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:781, in PythonParser._alert_malformed(self, msg, row_num)
#     764 """
#     765 Alert a user about a malformed row, depending on value of
#     766 `self.on_bad_lines` enum.
#    (...)    778     even though we 0-index internally.
#     779 """
#     780 if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 781     raise ParserError(msg)
#     782 if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     783     warnings.warn(
#     784         f"Skipping line {row_num}: {msg}\n",
#     785         ParserWarning,
#     786         stacklevel=find_stack_level(),
#     787     )
#
# ParserError: Expected 113 fields in line 3, saw 1036

# %%
with open(path, "r", encoding="utf-8", errors="strict") as f:
    for i in range(1, 8):
        line = f.readline()
        n_fields = line.count("\t") + 1
        print(f"LINE {i}: fields={n_fields}, chars={len(line)}")
# Out:
# LINE 1: fields=113, chars=5252
# LINE 2: fields=39, chars=1589
# LINE 3: fields=1036, chars=49136
# LINE 4: fields=1090, chars=51463
# LINE 5: fields=2275, chars=6764
# LINE 6: fields=2275, chars=39427
# LINE 7: fields=2275, chars=30579

# %%
import re
 
def is_time_start(s: str) -> bool:
    s = s.strip()
    # Accept common timestamp patterns: "2026-02-12 08:00:00" or "12.02.2026 08:00:00"
    return bool(re.match(r"^(\d{4}-\d{2}-\d{2}|\d{2}\.\d{2}\.\d{4})\s+\d{2}:\d{2}:\d{2}", s))
 
with open(path, "r", encoding="utf-8", errors="strict") as f:
    for idx, line in enumerate(f, start=1):
        first_cell = line.split("\t", 1)[0]
        if is_time_start(first_cell):
            print("First data row line number:", idx)
            print("First cell:", first_cell)
            print("Fields in this line:", line.count("\t") + 1)
            print("Preview:", repr(line[:200]))
            break
# Out:
# First data row line number: 7
# First cell: 2026-02-11 12:31:00
# Fields in this line: 2275
# Preview: '2026-02-11 12:31:00\t1143.977783203125\t1176.662521362305\t29.0759391784668\t4.692428038670467\t61.0427630497859\t89.01837686391977\t24.45834042475774\t2.836843508940476\t52.17922973632812\t88.99634199876051\t8.'

# %%
with open(path, "r", encoding="utf-8", errors="strict") as f:
    for i in range(1, 20):
        line = f.readline()
        n_fields = line.count("\t") + 1
        if n_fields == 2275:
            print("Found header-width line:", i)
            print("First 120 chars:", repr(line[:120]))
            print("Starts with:", repr(line.split("\t", 1)[0]))
# Out:
# Found header-width line: 5
# First 120 chars: '  \tM/MIN\tM/MIN\t%\tM3/HR\t%\tM3/HR\t%\tM3/HR\t%\tM3/HR\tM3/HR\t\tM3/HR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\tBAR\t%\tC\tBAR\tBAR\tBAR\tBAR\tBAR\t'
# Starts with: '  '
# Found header-width line: 6
# First 120 chars: '  \t2-003-UZ001-MD_SPEED-X\t2-033-UZ001-MD_SPEED-X\t2-033-FC100-Y\t2-033-FC100-X\t2-033-FC150-Y\t2-033-FC150-X\t2-033-FC200-Y\t2'
# Starts with: '  '
# Found header-width line: 7
# First 120 chars: '2026-02-11 12:31:00\t1143.977783203125\t1176.662521362305\t29.0759391784668\t4.692428038670467\t61.0427630497859\t89.018376863'
# Starts with: '2026-02-11 12:31:00'

# %%
df = pd.read_csv(
    path,
    sep="\t",
    skiprows=5,            # skip lines 1-5 (incl units row)
    header=0,              # line 6 becomes header
    encoding="utf-8",
    engine="python"
)
 
# Rename first column (blank header) to Time
df = df.rename(columns={df.columns[0]: "Time"})
df["Time"] = pd.to_datetime(df["Time"], errors="coerce")
 
print("Shape:", df.shape)
print("Columns (first 10):", df.columns[:10].to_list())
print(df[["Time"]].head())
print("Time nulls:", df["Time"].isna().sum())
# Out:
# Shape: (1, 2275)
# Columns (first 10): ['Time', '2-003-UZ001-MD_SPEED-X', '2-033-UZ001-MD_SPEED-X', '2-033-FC100-Y', '2-033-FC100-X', '2-033-FC150-Y', '2-033-FC150-X', '2-033-FC200-Y', '2-033-FC200-X', '2-033-FC250-Y']
#                  Time
# 0 2026-02-11 12:31:00
# Time nulls: 0

# %%
# --- 1) Read the known-good "units" and "tags" lines using plain text ---
def get_line(path, line_no, encoding="utf-8"):
    with open(path, "r", encoding=encoding, errors="strict") as f:
        for i, line in enumerate(f, start=1):
            if i == line_no:
                return line.rstrip("\n")
    raise ValueError(f"Line {line_no} not found")
 
units_line = get_line(path, 5)   # from our diagnosis
tags_line  = get_line(path, 6)
 
units = units_line.split("\t")
tags  = tags_line.split("\t")
 
# First cell is blank in both -> make it Time
tags[0] = "Time"
units[0] = "datetime"
 
# --- 2) Read the data safely, enforcing the expected number of columns ---
expected_cols = len(tags)  # should be 2275
 
# Use only the first expected_cols fields per row (protect against stray tabs later)
usecols = list(range(expected_cols))
 
df = pd.read_csv(
    path,
    sep="\t",
    skiprows=6,          # skip lines 1-6 (descriptions + units + tags)
    header=None,
    names=tags,
    usecols=usecols,
    encoding="utf-8",
    engine="python",
    on_bad_lines="skip", # if a row is truly broken, skip it instead of failing
)
 
# Parse Time
df["Time"] = pd.to_datetime(df["Time"], errors="coerce")
 
# --- 3) Build a metadata table: tag -> unit ---
meta = pd.DataFrame({"tag": tags, "unit": units})
 
print("Data shape:", df.shape)
print("Meta shape:", meta.shape)
print(meta.head(10))
print(df.head(3))
# Out:
# Data shape: (1, 2275)
# Meta shape: (2275, 2)
#                       tag      unit
# 0                    Time  datetime
# 1  2-003-UZ001-MD_SPEED-X     M/MIN
# 2  2-033-UZ001-MD_SPEED-X     M/MIN
# 3           2-033-FC100-Y         %
# 4           2-033-FC100-X     M3/HR
# 5           2-033-FC150-Y         %
# 6           2-033-FC150-X     M3/HR
# 7           2-033-FC200-Y         %
# 8           2-033-FC200-X     M3/HR
# 9           2-033-FC250-Y         %
#                  Time  2-003-UZ001-MD_SPEED-X  2-033-UZ001-MD_SPEED-X  \
# 0 2026-02-11 12:31:00             1143.977783             1176.662521
#
#    2-033-FC100-Y  2-033-FC100-X  2-033-FC150-Y  2-033-FC150-X  2-033-FC200-Y  \
# 0      29.075939       4.692428      61.042763      89.018377       24.45834
#
#    2-033-FC200-X  2-033-FC250-Y  ...  2-087-FI016_01  2-000-2A1J07-P  \
# 0       2.836844       52.17923  ...        72.39827       18.895373
#
#    2-008-FI041_25_2-X  2-008-FI041_05_2-X  2-008-LC041_05_2-X  \
# 0         1431.968848         1110.905628           82.487296
#
#    2-008-LC041_05_2-W  2-008-LC041_05_2-Y  2-008-LC041_25_2-X  \
# 0                  83            9.321958           84.725311
#
#    2-008-LC041_25_2-W  2-008-LC041_25_2-Y
# 0                  85           29.581066
#
# [1 rows x 2275 columns]

# %%
def get_line(path, line_no, encoding="utf-8"):
    with open(path, "r", encoding=encoding, errors="strict") as f:
        for i, line in enumerate(f, start=1):
            if i == line_no:
                return line.rstrip("\n")
    raise ValueError(f"Line {line_no} not found")
 
# Known from your diagnosis
desc_lines = [get_line(path, i) for i in [1, 2, 3, 4]]  # wrapped descriptions
units_line = get_line(path, 5)
tags_line  = get_line(path, 6)
 
# Split units/tags (these are full-width already)
units = units_line.split("\t")
tags  = tags_line.split("\t")
 
# Fix first column name/unit (blank -> Time)
tags[0] = "Time"
units[0] = "datetime"
 
expected_cols = len(tags)  # should be 2275
 
# --- Reconstruct descriptions by concatenating pieces from lines 1-4 ---
desc = []
for k, line in enumerate(desc_lines):
    parts = line.split("\t")
    if k == 0:
        # line 1 includes "Time" then first chunk of descriptions
        # keep same length as header chunk
        desc.extend(parts)
    else:
        # lines 2-4 start with a blank first field -> drop it
        if len(parts) > 0 and parts[0].strip() == "":
            parts = parts[1:]
        desc.extend(parts)
 
# Ensure descriptions align to expected column count
# (pad/truncate defensively in case of small off-by-few issues)
if len(desc) < expected_cols:
    desc = desc + [""] * (expected_cols - len(desc))
else:
    desc = desc[:expected_cols]
 
# Make sure first description is "Time" (optional)
if desc[0].strip() == "":
    desc[0] = "Time"
 
meta = pd.DataFrame({"tag": tags, "unit": units, "description": desc})
 
print("meta shape:", meta.shape)
print(meta.head(10))
# Out:
# meta shape: (2275, 3)
#                       tag      unit  \
# 0                    Time  datetime
# 1  2-003-UZ001-MD_SPEED-X     M/MIN
# 2  2-033-UZ001-MD_SPEED-X     M/MIN
# 3           2-033-FC100-Y         %
# 4           2-033-FC100-X     M3/HR
# 5           2-033-FC150-Y         %
# 6           2-033-FC150-X     M3/HR
# 7           2-033-FC200-Y         %
# 8           2-033-FC200-X     M3/HR
# 9           2-033-FC250-Y         %
#
#                                          description
# 0                                               Time
# 1   2-003-UZ001    Presse :  Istwert Geschwindigkeit
# 2  2-003-UZ001    Speedsizer :  Istwert Geschwind...
# 3  2-033-FC100    Stärke Arbeitsbehälter 1 :  Aus...
# 4  2-033-FC100    Stärke Arbeitsbehälter 1 :  Mes...
# 5      2-033-FC150    Stärke Speedsizer 1 :  Ausgang
# 6     2-033-FC150    Stärke Speedsizer 1 :  Messwert
# 7  2-033-FC200    Stärke Arbeitsbehälter 2 :  Aus...
# 8  2-033-FC200    Stärke Arbeitsbehälter 2 :  Mes...
# 9      2-033-FC250    Stärke Speedsizer 2 :  Ausgang

# %%
import re
import unicodedata
import pandas as pd
 
# --- compiled regexes (fast) ---
 
# tag-like substrings such as 2-033-FI100-D2 or 2-033-FC100
TAG_LIKE = re.compile(r"\b\d+-\d+-[A-Z0-9]+(?:-[A-Z0-9]+)?\b")
 
# complete bracket blocks: [ ... ]
FULL_BRACKET = re.compile(r"\[[^\]]*\]")
 
# dangling bracket interval at end (no closing ])
DANGLING_INTERVAL = re.compile(
    r"\[\s*[-+]?\d+(?:[.,]\d+)?\s*\.\.\s*[-+]?\d+(?:[.,]\d+)?[^]]*$"
)
 
# any remaining lone '['
LONE_OPEN_BRACKET = re.compile(r"\[")
 
# suffix ~^n at end
SUFFIX = re.compile(r"\s*~\^(\d+)\s*$")
 
# invisible characters explicitly
ZW_BOM = re.compile(r"[\u200b\u200c\u200d\u2060\ufeff]")
 
# unit mentions (add more as needed)
UNIT_PATTERNS = [
    r"\(\s*%+\s*\)",
    r"\(\s*vol\s*%\s*\)",
    r"\(\s*vol%\s*\)",
 
    r"\b(in)\s+kwh\b",
    r"\b(in)\s+mwh\b",
    r"\b(in)\s+g\s*/\s*m(?:\^?2|²)\b",
 
    r"\bt\s*/\s*hr\b",
    r"\bl\s*/\s*h\b",
    r"\bl\s*/\s*min\b",
    r"\bm\s*/\s*min\b",
    r"\bm(?:\^?2|²)\b",
    r"\bg\s*/\s*m(?:\^?2|²)\b",
    r"\bm(?:\^?3|³)\s*/\s*h\b",
 
    r"\bkwh\b",
    r"\bmwh\b",
 
    r"\b\d+(?:[.,]\d+)?\s*(?:-|–|\.\.)\s*\d+(?:[.,]\d+)?\s*bar\b",
]
UNITS_RE = re.compile("|".join(f"(?:{p})" for p in UNIT_PATTERNS), flags=re.IGNORECASE)
 
# logic notes to remove
LOGIC_RE = re.compile(
    r"(?:\(\s*0\s*=\s*false\s*\))"
    r"|(?:/\s*no\s*tear\s*=\s*-?1\s*\|\s*tear\s*=\s*0)",
    flags=re.IGNORECASE
)
 
def clean_meta_text(x: object) -> object:
    """Apply all cleaning steps to a single cell."""
    if pd.isna(x):
        return x
 
    s = str(x)
 
    # 1) remove zero-width + BOM explicitly
    s = ZW_BOM.sub("", s)
 
    # 2) remove other unicode control chars (category starts with 'C')
    s = "".join(ch for ch in s if unicodedata.category(ch)[0] != "C")
 
    # 3) ~^n -> (n+1)
    m = SUFFIX.search(s)
    if m:
        n = int(m.group(1))
        s = SUFFIX.sub(f" ({n+1})", s)
 
    # 4) remove tag-like substrings
    s = TAG_LIKE.sub("", s)
 
    # 5) remove proper bracket blocks and dangling intervals
    #s = FULL_BRACKET.sub("", s)
    #s = DANGLING_INTERVAL.sub("", s)
    #s = LONE_OPEN_BRACKET.sub("", s)
 
    # 6) remove logic notes
    #s = LOGIC_RE.sub("", s)
 
    # 7) remove unit mentions
    #s = UNITS_RE.sub("", s)
 
    # 8) normalize whitespace and tidy punctuation leftovers
    s = re.sub(r"\s+", " ", s).strip()
    s = re.sub(r"\s*:\s*$", "", s).strip()

       # 8) normalize whitespace
    s = re.sub(r"\s+", " ", s).strip()
 
    # Remove trailing colon
    s = re.sub(r"\s*:\s*$", "", s).strip()
 
    # Remove leading/trailing dots
    s = re.sub(r"^\.+\s*", "", s)   # dots at start
    s = re.sub(r"\s*\.+$", "", s)   # dots at end
 
    # Final trim
    s = s.strip()
 
    return s
 
def clean_meta_dataframe(meta: pd.DataFrame, columns: list[str]) -> pd.DataFrame:
    """Clean selected columns in meta in-place and return meta."""
    for c in columns:
        if c in meta.columns:
            meta[c] = meta[c].apply(clean_meta_text)
    return meta
 
# --- usage: choose the columns you want cleaned (German + English if present) ---
#cols_to_clean = ["machine_part", "description_text", "machine_part_en", "description_text_en"]
cols_to_clean = ["description"]
meta = clean_meta_dataframe(meta, cols_to_clean)
 
meta[cols_to_clean].head(15)
# Out:
#                                 description
# 0                                      Time
# 1          Presse : Istwert Geschwindigkeit
# 2      Speedsizer : Istwert Geschwindigkeit
# 3        Stärke Arbeitsbehälter 1 : Ausgang
# 4       Stärke Arbeitsbehälter 1 : Messwert
# 5             Stärke Speedsizer 1 : Ausgang
# 6            Stärke Speedsizer 1 : Messwert
# 7        Stärke Arbeitsbehälter 2 : Ausgang
# 8       Stärke Arbeitsbehälter 2 : Messwert
# 9             Stärke Speedsizer 2 : Ausgang
# 10           Stärke Speedsizer 2 : Messwert
# 11              Konz. STärke AB1 : Messwert
# 12  Staerkeauftrag BW : MESSWERT in [ml/m²]
# 13              Konz. STärke AB2 : Messwert
# 14       Diff.Druck Filter 1 AB1 : Messwert

# %%
# Split only on the FIRST colon
split_cols = meta["description"].str.split(":", n=1, expand=True)
 
meta["machine_part"] = split_cols[0].str.strip()
 
# If there is no colon, second column will be NaN → replace with empty string
meta["description_text"] = (
    split_cols[1]
    .fillna("")
    .str.strip()
)
 
print(meta[["machine_part", "description_text"]].head(10))
# Out:
#                               machine_part         description_text
# 0
# 1                    2-003-UZ001    Presse  Istwert Geschwindigkeit
# 2                2-003-UZ001    Speedsizer  Istwert Geschwindigkeit
# 3  2-033-FC100    Stärke Arbeitsbehälter 1                  Ausgang
# 4  2-033-FC100    Stärke Arbeitsbehälter 1                 Messwert
# 5       2-033-FC150    Stärke Speedsizer 1                  Ausgang
# 6       2-033-FC150    Stärke Speedsizer 1                 Messwert
# 7  2-033-FC200    Stärke Arbeitsbehälter 2                  Ausgang
# 8  2-033-FC200    Stärke Arbeitsbehälter 2                 Messwert
# 9       2-033-FC250    Stärke Speedsizer 2                  Ausgang

# %%
import boto3
import json
import pandas as pd
from tqdm.auto import tqdm
import os

os.environ["AWS_ACCESS_KEY_ID"] = "ASIA3MADJBNO2UB5PZIE"
os.environ["AWS_SECRET_ACCESS_KEY"] = "lzxqANjxs/a39MBOfPqIRLPSYX2tUdF+i/+2FzHe"
os.environ["AWS_SESSION_TOKEN"] = "..."
os.environ["AWS_REGION"] = "eu-west-1"
 
bedrock = boto3.client("bedrock-runtime", region_name="eu-west-1")
MODEL_ID = "arn:aws:bedrock:eu-west-1:781690932061:inference-profile/eu.anthropic.claude-sonnet-4-5-20250929-v1:0"

SYSTEM_PROMPT = """You are a professional industrial translator.
Translate German industrial variable names into precise technical English.
 
Rules:
- Preserve technical meaning.
- Do not expand plant codes or IDs.
- Do not explain.
- Output MUST be JSON Lines (JSONL): one JSON object per line.
- Each line format: {"src": "<original>", "tgt": "<translation>"}
- Output only JSONL lines, no markdown, no extra text.
"""
 
def _parse_jsonl(text: str) -> dict:
    if not text or not text.strip():
        raise ValueError("Empty model text")
 
    # remove code fences if any
    text = re.sub(r"^```(?:jsonl|json)?\s*", "", text.strip(), flags=re.IGNORECASE)
    text = re.sub(r"\s*```$", "", text)
 
    mapping = {}
    bad = 0
    for line in text.splitlines():
        line = line.strip()
        if not line:
            continue
        try:
            obj = json.loads(line)
            mapping[obj["src"]] = obj["tgt"]
        except Exception:
            bad += 1
 
    if not mapping:
        raise ValueError(f"No JSONL objects parsed. First 200 chars: {text[:200]!r}")
    return mapping
 
def translate_batch_bedrock_jsonl(strings, max_retries=2):
    user_prompt = "Translate these terms into English. Return JSONL only.\n"
    user_prompt += "\n".join(f"- {s}" for s in strings)
 
    body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 3500,      # keep some headroom
        "temperature": 0,
        "system": SYSTEM_PROMPT,
        "messages": [{"role": "user", "content": user_prompt}],
    }
 
    last_err = None
    for attempt in range(max_retries + 1):
        resp = bedrock.invoke_model(modelId=MODEL_ID, body=json.dumps(body))
        payload = json.loads(resp["body"].read())
        text = payload.get("content", [{}])[0].get("text", "")
 
        try:
            out = _parse_jsonl(text)
            # Fill missing with original
            for s in strings:
                out.setdefault(s, s)
            return out
        except Exception as e:
            last_err = e
            body["messages"].append({
                "role": "user",
                "content": "Your output was not valid JSONL. Output ONLY JSONL lines, one per input bullet."
            })
            time.sleep(0.5)
 
    raise RuntimeError(f"Failed JSONL. Last error: {last_err}")
 
def translate_unique_with_bedrock(values, batch_size=50, min_batch_size=5):
    values = pd.Series(values).dropna().astype(str)
    values = values[values.str.strip() != ""]
    unique_vals = values.unique().tolist()
 
    mapping = {}
    i = 0
    pbar = tqdm(total=len(unique_vals), desc="Translating (Bedrock)", unit="str")
 
    while i < len(unique_vals):
        bs = min(batch_size, len(unique_vals) - i)
        batch = unique_vals[i:i+bs]
 
        try:
            out = translate_batch_bedrock_jsonl(batch)
            mapping.update(out)
            i += bs
            pbar.update(bs)
        except RuntimeError:
            # If it fails, reduce batch size and retry this same chunk
            if bs <= min_batch_size:
                # last resort: keep originals to avoid infinite loop
                for s in batch:
                    mapping.setdefault(s, s)
                i += bs
                pbar.update(bs)
            else:
                batch_size = max(min_batch_size, bs // 2)
 
    pbar.close()
    return mapping
 
# Example usage
desc_map = translate_unique_with_bedrock(meta["description"].unique(), batch_size=80)
 
meta["description_en"] = meta["description"].map(desc_map)
# Out:
# Translating (Bedrock):   0%|          | 0/2258 [00:00<?, ?str/s]

# %%
meta_=meta.copy()

# %%
meta=meta_.copy()

# %%
meta.shape
# Out:
# (2275, 4)

# %%
ADIOS
meta.head(15)
# Out:
#                        tag      unit                              description  \
# 0                     Time  datetime                                     Time
# 1   2-003-UZ001-MD_SPEED-X     M/MIN         Presse : Istwert Geschwindigkeit
# 2   2-033-UZ001-MD_SPEED-X     M/MIN     Speedsizer : Istwert Geschwindigkeit
# 3            2-033-FC100-Y         %       Stärke Arbeitsbehälter 1 : Ausgang
# 4            2-033-FC100-X     M3/HR      Stärke Arbeitsbehälter 1 : Messwert
# 5            2-033-FC150-Y         %            Stärke Speedsizer 1 : Ausgang
# 6            2-033-FC150-X     M3/HR           Stärke Speedsizer 1 : Messwert
# 7            2-033-FC200-Y         %       Stärke Arbeitsbehälter 2 : Ausgang
# 8            2-033-FC200-X     M3/HR      Stärke Arbeitsbehälter 2 : Messwert
# 9            2-033-FC250-Y         %            Stärke Speedsizer 2 : Ausgang
# 10           2-033-FC250-X     M3/HR           Stärke Speedsizer 2 : Messwert
# 11           2-033-FI100-X     M3/HR              Konz. STärke AB1 : Messwert
# 12        2-033-FI100-D2-X            Staerkeauftrag BW : MESSWERT in [ml/m²]
# 13           2-033-FI200-X     M3/HR              Konz. STärke AB2 : Messwert
# 14           2-033-PD110-X       BAR       Diff.Druck Filter 1 AB1 : Messwert
#
#                                        description_en
# 0                                                Time
# 1                                Press : Actual Speed
# 2                           Speedsizer : Actual Speed
# 3                 Starch Working Container 1 : Output
# 4         Starch Working Container 1 : Measured Value
# 5                        Starch Speedsizer 1 : Output
# 6                Starch Speedsizer 1 : Measured Value
# 7                 Starch Working Container 2 : Output
# 8         Starch Working Container 2 : Measured Value
# 9                        Starch Speedsizer 2 : Output
# 10               Starch Speedsizer 2 : Measured Value
# 11                  Conc. Starch AB1 : Measured Value
# 12  Starch Application BW : MEASURED VALUE in [ml/m²]
# 13                  Conc. Starch AB2 : Measured Value
# 14       Diff. Pressure Filter 1 AB1 : Measured Value

# %%
meta[meta.tag=="1-000-EI005_9_1-X"]
# Out:
# Empty DataFrame
# Columns: [tag, unit, description, description_en]
# Index: []

# %%
meta[meta.description_en.str.lower().str.contains("moist")]
# Out:
#                           tag   unit  \
# 249    QLS-REEL-MOISTURE1-CUR
# 250    QLS-REEL-MOISTURE2-CUR
# 699            2-033-FI100-D3      %
# 700      QMS11_MIC_MSTSCN1-X1    PCT
# 701      QMS11_MIC_MSTSCN2-X1    PCT
# 702       PM1-MO1-RL:GFLT.SIG
# 703       PM1-MO1-RL:GFLT.MAX      %
# 704       PM1-MO1-RL:GFLT.MIN      %
# 705       PM1-MO1-RL:GFLT.AVG      %
# 706      PM1-MO1-RL:CHOPSPEED  1/min
# 707          PM1-MO1-RL:DHHUM      %
# 708          PM1-MO1-RL:SHHUM      %
# 709        PM1-MO1-RL:SHPOWER      %
# 710        PM1-MO1-RL:DHPOWER      W
# 711       PM1-MO1-RL:GRAW.SIG
# 712       PM1-MO1-RL:GRAW.MAX      %
# 713       PM1-MO1-RL:GRAW.MIN      %
# 728        PM1-MZ1-SP:ODWGTIV   g/m2
# 729       PM1-PM1-SP:GRAW.SIG
# 730       PM1-PM1-SP:GRAW.MAX      %
# 731       PM1-PM1-SP:GRAW.MIN      %
# 732       PM1-PM1-SP:GRAW.AVG      %
# 733          PM1-MZ1-SP:SHTMP      C
# 734         PM1-MZ1-SP:WWGTIV   g/m2
# 1010  QLS-REEL-MOISTURE1-LAST
# 1011  QLS-REEL-MOISTURE2-LAST
# 1080       PM1-PMRL.CP:ERRVAR      %
# 1473             QO_FEU_AL400
# 1474          QO_FEUCHT_2S_MD
# 1475       QO_FEUCHT_2S_TOT15
# 1476         QO_FEUCHT_2S_CD6
# 1477            QO_FEUCHT_ADJ
# 1478        QO_FEUCHT_NORM_MD
# 1479       QO_FEUCHT_TOTVAR15
# 1480       QO_FEUCHT_VAR_CD15
# 1481         QO_FEUCHT_VAR_MD
# 1482        QO_FEUCHTE_ONLINE
# 1541          PM1-PMRL.OPR:MA
# 1542          PM1-PMRL.OPR:ME      %
# 1543         PM1-PMRL.OPR:POS    bar
# 1544         PM1-PMRL.OPR:SPA      %
# 1545          PM1-PMSP.OPR:MA
# 1546          PM1-PMSP.OPR:ME      %
# 1547         PM1-PMSP.OPR:POS    bar
# 1548         PM1-PMSP.OPR:SPA      %
#
#                                             description  \
# 249           Current reel moisture average(Aufrollung)
# 250           Current reel moisture average(Leimpresse)
# 699                   Feuchte nach SpeedSizer [0..50 %]
# 700                       Feuchte NTP Poperoller 0-15 %
# 701                        Feuchte VTP Speedsizer 0-15%
# 702   Feuchtemessung Pope gefiltertes Profil 2 sigma...
# 703   Feuchtemessung Pope gefiltertes Profil Maximal...
# 704   Feuchtemessung Pope gefiltertes Profil Minimum...
# 705   Feuchtemessung Pope gefiltertes Profil Mittelw...
# 706   Feuchtemessung Pope Geschwindigkeit Lichtzerha...
# 707   Feuchtemessung Pope interne Luftfeuchte Detect...
# 708   Feuchtemessung Pope interne Luftfeuchte Sorce ...
# 709   Feuchtemessung Pope interne Luftfeuchte Source...
# 710   Feuchtemessung Pope Leistungsaufnahme Detector...
# 711      Feuchtemessung Pope Rohprofil 2 sigma [0..20 ]
# 712   Feuchtemessung Pope Rohprofil Maximalwert [0.....
# 713   Feuchtemessung Pope Rohprofil Minimumwert [0.....
# 728   Feuchtemessung Sizer Otro aktueller Wert [0..1...
# 729     Feuchtemessung Sizer Rohprofil 2 sigma [0..20 ]
# 730   Feuchtemessung Sizer Rohprofil Maximalwert [0....
# 731   Feuchtemessung Sizer Rohprofil Minimumwert [0....
# 732   Feuchtemessung Sizer Rohprofil Mittelwert [0.....
# 733          Feuchtemessung Sizer Temperatur [0..100 C]
# 734   Feuchtemessung Sizer Wassergewicht aktueller W...
# 1010             Last reel moisture average(Aufrollung)
# 1011             Last reel moisture average(Leimpresse)
# 1080                      MD COV Feuchte Pope [0..10 %]
# 1473                                       QO_Feu AL400
# 1474                                QO_Feucht 2s MD E10
# 1475             QO_Feucht 2s TOT15 G14 Feucht 2s TOT15
# 1476                                QO_Feucht 2sCD6 D09
# 1477               QO_Feucht ADJ Calculation AX-A5 V1.0
# 1478                    QO_Feucht NORM MD Normalised MD
# 1479  QO_Feucht TOTVAR15 F13 Total variation moistur...
# 1480             QO_Feucht VAR CD15 C12 Feucht VAR CD15
# 1481  QO_Feucht VAR MD A06 Feucht VAR MD Feucht VAR ...
# 1482  QO_Feuchte Online Feuchte Poperoller Feuchte O...
# 1541                    Regler Feuchte Pope M/A [0..1 ]
# 1542              Regler Feuchte Pope Messung [0..30 %]
# 1543       Regler Feuchte Pope Reglerausgang [0..8 bar]
# 1544             Regler Feuchte Pope Sollwert [0..30 %]
# 1545                   Regler Feuchte Sizer M/A [0..1 ]
# 1546             Regler Feuchte Sizer Messung [0..30 %]
# 1547      Regler Feuchte Sizer Reglerausgang [0..8 bar]
# 1548            Regler Feuchte Sizer Sollwert [0..30 %]
#
#                                          description_en
# 249             Current reel moisture average (winding)
# 250          Current reel moisture average (size press)
# 699                 Moisture after SpeedSizer [0..50 %]
# 700                      Moisture NTP Poperoller 0-15 %
# 701                       Moisture VTP Speedsizer 0-15%
# 702   Moisture measurement Pope filtered profile 2 s...
# 703   Moisture measurement Pope filtered profile max...
# 704   Moisture measurement Pope filtered profile min...
# 705   Moisture measurement Pope filtered profile mea...
# 706   Moisture measurement Pope speed light chopper ...
# 707   Moisture measurement Pope internal air humidit...
# 708   Moisture measurement Pope internal air humidit...
# 709   Moisture measurement Pope internal air humidit...
# 710   Moisture measurement Pope power consumption de...
# 711   Moisture measurement Pope raw profile 2 sigma ...
# 712   Moisture measurement Pope raw profile maximum ...
# 713   Moisture measurement Pope raw profile minimum ...
# 728   Moisture measurement Sizer Otro actual value [...
# 729   Moisture measurement Sizer raw profile 2 sigma...
# 730   Moisture measurement Sizer raw profile maximum...
# 731   Moisture measurement Sizer raw profile minimum...
# 732   Moisture measurement Sizer raw profile mean va...
# 733   Moisture measurement Sizer temperature [0..100 C]
# 734   Moisture measurement Sizer water weight actual...
# 1010                Last reel moisture average(reeling)
# 1011             Last reel moisture average(size press)
# 1080                     MD COV Moisture Pope [0..10 %]
# 1473                                  QO_moisture AL400
# 1474                              QO_moisture 2s MD E10
# 1475         QO_moisture 2s TOT15 G14 moisture 2s TOT15
# 1476                              QO_moisture 2sCD6 D09
# 1477             QO_moisture ADJ Calculation AX-A5 V1.0
# 1478                  QO_moisture NORM MD Normalised MD
# 1479  QO_moisture TOTVAR15 F13 Total variation moist...
# 1480         QO_moisture VAR CD15 C12 moisture VAR CD15
# 1481  QO_moisture VAR MD A06 moisture VAR MD moistur...
# 1482  QO_moisture online moisture pope roller moistu...
# 1541               Controller Moisture Pope M/A [0..1 ]
# 1542     Controller Moisture Pope Measurement [0..30 %]
# 1543  Controller Moisture Pope Controller Output [0....
# 1544        Controller Moisture Pope Setpoint [0..30 %]
# 1545              Controller Moisture Sizer M/A [0..1 ]
# 1546    Controller Moisture Sizer Measurement [0..30 %]
# 1547  Controller Moisture Sizer Controller Output [0...
# 1548       Controller Moisture Sizer Setpoint [0..30 %]

# %%
import pandas as pd
 
# Create new row as dictionary
new_row = {
    "tag": "R2NAE20CF905",
    "unit": "t/h",
    "description": "Abdampf",
    "description_en": "Waste steam"
}
 
# Append to meta
meta = pd.concat([meta, pd.DataFrame([new_row])], ignore_index=True)
 
# Optional: verify
meta.tail()
# Out:
#                      tag unit  \
# 2271  2-008-LC041_05_2-Y    %
# 2272  2-008-LC041_25_2-X    %
# 2273  2-008-LC041_25_2-W    %
# 2274  2-008-LC041_25_2-Y    %
# 2275        R2NAE20CF905  t/h
#
#                                             description  \
# 2271  Überlauf Stoff-Deculator B41.5 : Stellwert [-1...
# 2272  Überlauf Verd.wasser-Deculator B41.25 : Messwe...
# 2273  Überlauf Verd.wasser-Deculator B41.25 : Sollwe...
# 2274  Überlauf Verd.wasser-Deculator B41.25 : Stellw...
# 2275                                            Abdampf
#
#                                          description_en
# 2271  Overflow stock deculator B41.5 : Control value...
# 2272  Overflow dilution water deculator B41.25 : Mea...
# 2273  Overflow dilution water deculator B41.25 : Set...
# 2274  Überlauf Verd.wasser-Deculator B41.25 : Stellw...
# 2275                                        Waste steam

# %%
import pandas as pd
 
# New tags to add
new_rows = [
    # MF1
    {"description_en": "Multifractor 1 long fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_4-X",
     "description": "Multifraktor 1 Langfaser Durchfluss"},
    {"description_en": "Multifractor 1 short fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_3-X",
     "description": "Multifraktor 1 Kurzfaser Durchfluss"},
    {"description_en": "Multifractor 1 consistency",
     "unit": "%",
     "tag": "1-000-CC005_1_1-X",
     "description": "Multifraktor 1 Stoffdichte"},
 
    # MF2
    {"description_en": "Multifractor 2 long fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_2-X",
     "description": "Multifraktor 2 Langfaser Durchfluss"},
    {"description_en": "Multifractor 2 short fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_1-X",
     "description": "Multifraktor 2 Kurzfaser Durchfluss"},
    {"description_en": "Multifractor 2 consistency",
     "unit": "%",
     "tag": "1-000-CC005_1_2-X",
     "description": "Multifraktor 2 Stoffdichte"},
 
    # MF3
    {"description_en": "Multifractor 3 long fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_8_1-X",
     "description": "Multifraktor 3 Langfaser Durchfluss"},
    {"description_en": "Multifractor 3 short fibre flow",
     "unit": "m³/h",
     "tag": "1-000-FC005_8_2-X",
     "description": "Multifraktor 3 Kurzfaser Durchfluss"},
    {"description_en": "Multifractor 3 consistency",
     "unit": "%",
     "tag": "1-000-CC005_1_3-X",
     "description": "Multifraktor 3 Stoffdichte"},
]
 
new_df = pd.DataFrame(new_rows)
 
# Ensure same column order as meta
new_df = new_df[meta.columns.intersection(new_df.columns)]
 
# Append
meta = pd.concat([meta, new_df], ignore_index=True)
 
# Optional: drop duplicates by tag (safe upsert behaviour)
meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
import pandas as pd
import numpy as np
 
# New rows to add
new_rows = [
    {
        "description_en": "Condensate energy from paper plant to power plant",
        "description": "Kondensatenergie von der Papierfabrik zum Kraftwerk",
        "unit": np.nan,  # unknown / not provided
        "tag": "GMC_A1_G1LDA10CF701_WF",
        "TagNumber": np.nan,
    },
    {
        "description_en": "Short fibre B06 consistency",
        "description": "Kurzfaser B06 Stoffdichte",
        "unit": "%",
        "tag": "1-000-CC006_01-X",
        "TagNumber": np.nan,
    },
    {
        "description_en": "Long fibre consistency B07",
        "description": "Langfaser B07 Stoffdichte",
        "unit": "%",
        "tag": "1-000-CC007_01-X",
        "TagNumber": 8143,
    },
    {
        "description_en": "Inlet Thickener 2 flow",
        "description": "Zulauf Eindicker 2 Durchfluss",
        "unit": "m3/h",   # normalized from [m3/h]
        "tag": "1-000-FC018_2-X",
        "TagNumber": np.nan,
    },
]
 
new_df = pd.DataFrame(new_rows)
 
# Align to meta columns (keeps only columns that exist in meta)
new_df = new_df.reindex(columns=meta.columns)
 
# Append + upsert by tag
meta = pd.concat([meta, new_df], ignore_index=True)
 
if "tag" in meta.columns:
    meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
import pandas as pd
import numpy as np
 
new_rows = [
    {
        "description": "Retentionsmittel Menge l/h [0..9000 l/h]",
        "description_en": "Retention aid flow rate",
        "unit": "l/h",
        "tag": "2-008-FC083.01-X",
        "TagNumber": np.nan,
    },
    {
        "description": "Fixiermittelmenge Trockenausschuss [0..100 l/h]",
        "description_en": "Fixing agent flow rate reject",
        "unit": "l/h",
        "tag": "2-008-FC080_02_3-X",
        "TagNumber": np.nan,
    },
    {
        "description": "NaOH-Dosierung Pulper : MESSWERT",
        "description_en": "NaOH dosing pulper: measured value",
        "unit": np.nan,
        "tag": "1-000-FC028_01-X",
        "TagNumber": np.nan,
    },
]
 
new_df = pd.DataFrame(new_rows)
 
# Align with meta structure
new_df = new_df.reindex(columns=meta.columns)
 
# Append + upsert by tag
meta = pd.concat([meta, new_df], ignore_index=True)
 
if "tag" in meta.columns:
    meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
import pandas as pd
import numpy as np
 
new_rows = [
    {
        "description": "NaOH-Dosierung Kurzfaser-SF :  MESSWERT",
        "description_en": "NaOH dosing short fibre (SF): measured value",
        "unit": np.nan,
        "tag": "1-000-FC028_02-X",
        "TagNumber": np.nan,
    }
]
 
new_df = pd.DataFrame(new_rows)
 
# Align with meta structure
new_df = new_df.reindex(columns=meta.columns)
 
# Append + upsert
meta = pd.concat([meta, new_df], ignore_index=True)
 
if "tag" in meta.columns:
    meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
import pandas as pd
import numpy as np
 
new_rows = [
    {
        "description": "NaOH-Dosierung Langfaser-SF :  MESSWERT",
        "description_en": "NaOH dosing long fibre (SF): measured value",
        "unit": np.nan,
        "tag": "1-000-FC028_03-X",
        "TagNumber": np.nan,
    }
]
 
new_df = pd.DataFrame(new_rows)
 
# Align with meta structure
new_df = new_df.reindex(columns=meta.columns)
 
# Append + upsert by tag
meta = pd.concat([meta, new_df], ignore_index=True)
 
if "tag" in meta.columns:
    meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
#HOLA
import pandas as pd
import numpy as np
 
new_rows = [
    {
        "description": "Presse : Istwert Geschwindigkeit",
        "description_en": "Press : Actual Speed",
        "unit": "M/MIN",
        "tag": "2-003-UZ001-MD_SPEED-X",
        "TagNumber": np.nan,
    },
    {
        "description": "Speedsizer : Istwert Geschwindigkeit",
        "description_en": "Speedsizer : Actual Speed",
        "unit": "M/MIN",
        "tag": "2-033-UZ001-MD_SPEED-X",
        "TagNumber": np.nan,
    },
    
]
 
new_df = pd.DataFrame(new_rows)
 
# Align with meta structure
new_df = new_df.reindex(columns=meta.columns)
 
# Append + upsert by tag
meta = pd.concat([meta, new_df], ignore_index=True)
 
if "tag" in meta.columns:
    meta = meta.drop_duplicates(subset="tag", keep="last").reset_index(drop=True)

# %%
meta.tail(15)
# Out:
#                          tag   unit  \
# 2276       1-000-CC005_1_2-X      %
# 2277       1-000-FC005_8_1-X   m³/h
# 2278       1-000-FC005_8_2-X   m³/h
# 2279       1-000-CC005_1_3-X      %
# 2280  GMC_A1_G1LDA10CF701_WF   None
# 2281        1-000-CC006_01-X      %
# 2282        1-000-CC007_01-X      %
# 2283         1-000-FC018_2-X   m3/h
# 2284        2-008-FC083.01-X    l/h
# 2285      2-008-FC080_02_3-X    l/h
# 2286        1-000-FC028_01-X   None
# 2287        1-000-FC028_02-X   None
# 2288        1-000-FC028_03-X   None
# 2289  2-003-UZ001-MD_SPEED-X  M/MIN
# 2290  2-033-UZ001-MD_SPEED-X  M/MIN
#
#                                             description  \
# 2276                         Multifraktor 2 Stoffdichte
# 2277                Multifraktor 3 Langfaser Durchfluss
# 2278                Multifraktor 3 Kurzfaser Durchfluss
# 2279                         Multifraktor 3 Stoffdichte
# 2280  Kondensatenergie von der Papierfabrik zum Kraf...
# 2281                          Kurzfaser B06 Stoffdichte
# 2282                          Langfaser B07 Stoffdichte
# 2283                      Zulauf Eindicker 2 Durchfluss
# 2284           Retentionsmittel Menge l/h [0..9000 l/h]
# 2285    Fixiermittelmenge Trockenausschuss [0..100 l/h]
# 2286                   NaOH-Dosierung Pulper : MESSWERT
# 2287            NaOH-Dosierung Kurzfaser-SF :  MESSWERT
# 2288            NaOH-Dosierung Langfaser-SF :  MESSWERT
# 2289                   Presse : Istwert Geschwindigkeit
# 2290               Speedsizer : Istwert Geschwindigkeit
#
#                                          description_en
# 2276                         Multifractor 2 consistency
# 2277                     Multifractor 3 long fibre flow
# 2278                    Multifractor 3 short fibre flow
# 2279                         Multifractor 3 consistency
# 2280  Condensate energy from paper plant to power plant
# 2281                        Short fibre B06 consistency
# 2282                         Long fibre consistency B07
# 2283                             Inlet Thickener 2 flow
# 2284                            Retention aid flow rate
# 2285                      Fixing agent flow rate reject
# 2286                 NaOH dosing pulper: measured value
# 2287       NaOH dosing short fibre (SF): measured value
# 2288        NaOH dosing long fibre (SF): measured value
# 2289                               Press : Actual Speed
# 2290                          Speedsizer : Actual Speed

# %%
import pandas as pd
meta=pd.read_parquet("complete_tags.parquet")[1:]

# %%
meta.tail()
# Out:
#                      tag unit  \
# 2285    2-008-FC083.01-X  l/h
# 2286  2-008-FC080_02_3-X  l/h
# 2287    1-000-FC028_01-X  NaN
# 2288    1-000-FC028_02-X  NaN
# 2289    1-000-FC028_03-X  NaN
#
#                                           description  \
# 2285         Retentionsmittel Menge l/h [0..9000 l/h]
# 2286  Fixiermittelmenge Trockenausschuss [0..100 l/h]
# 2287                 NaOH-Dosierung Pulper : MESSWERT
# 2288          NaOH-Dosierung Kurzfaser-SF :  MESSWERT
# 2289          NaOH-Dosierung Langfaser-SF :  MESSWERT
#
#                                     description_en
# 2285                       Retention aid flow rate
# 2286                 Fixing agent flow rate reject
# 2287            NaOH dosing pulper: measured value
# 2288  NaOH dosing short fibre (SF): measured value
# 2289   NaOH dosing long fibre (SF): measured value

# %%
meta.to_parquet("complete_tags.parquet")

# %%
"2-033-UZ001-MD_SPEED-X" in meta.tag.to_list()
# Out:
# False

# %%
"2-044-TC413-X" in meta.tag
# Out:
# False

# %%
meta[meta.description_en.isin([desc for desc in meta.description_en if "tp4" in desc.lower()])]
# Out:
#                         tag  unit  \
# 37            2-044-PC404-Y     %
# 38            2-044-PC404-X    Pa
# 39            2-044-PC416-Y     %
# 40            2-044-PC416-X    Pa
# 41            2-044-PC443-Y     %
# 42            2-044-PC443-X    Pa
# 54            2-044-TC413-Y     %
# 55            2-044-TC413-X     C
# 56            2-044-TC413-W     C
# 443   QMS11_2-044-V431-N_FU     %
# 462   QMS11_2-044-V411-N_FU     %
# 694     QMS11_2-044-MC433-X  G/KG
# 695           2-044-MC433-Y     %
# 1070          2-044-PC416-W    Pa
# 1324         2-044-TI704_NL     m
# 1325          2-044-PC404-W    Pa
# 1424          2-044-PC443-W    Pa
#
#                                             description  \
# 37                            Nulllinie TP4-5 : Ausgang
# 38                           Nulllinie TP4-5 : Messwert
# 39                             Luftmesser TP4 : Ausgang
# 40                            Luftmesser TP4 : Messwert
# 41                             Prorelease TP4 : Ausgang
# 42                            Prorelease TP4 : Messwert
# 54                           Temp. Zuluft TP4 : Ausgang
# 55                          Temp. Zuluft TP4 : Messwert
# 56                          Temp. Zuluft TP4 : Sollwert
# 443            Drehzahl Abluft Ventilator TP4 [0-100 %]
# 462            Drehzahl Zuluft Ventilator TP4 [0-100 %]
# 694    Feuchte Abluft TP4 : Messwert [0..200 g/kg d.a.]
# 695       Feuchte Abluft TP4 : REGLERAUSGANG [0..100 %]
# 1070  Luftmesser TP4 : SETPOINT TO CONTROLLER [0..50...
# 1324                           Nulllinie TP4+5 [0..2 m]
# 1325  Nulllinie TP4-5 : SETPOINT TO CONTROLLER [-50....
# 1424  Prorelease TP4 : SETPOINT TO CONTROLLER [-5000...
#
#                                          description_en
# 37                             Zero Line TP4-5 : Output
# 38                     Zero Line TP4-5 : Measured Value
# 39                               Air Knife TP4 : Output
# 40                       Air Knife TP4 : Measured Value
# 41                              Prorelease TP4 : Output
# 42                      Prorelease TP4 : Measured Value
# 54                        Temp. Supply Air TP4 : Output
# 55                Temp. Supply Air TP4 : Measured Value
# 56                      Temp. Supply Air TP4 : Setpoint
# 443                 Speed exhaust air fan TP4 [0-100 %]
# 462                  Speed supply air fan TP4 [0-100 %]
# 694   Humidity exhaust air TP4 : Measured value [0.....
# 695   Humidity exhaust air TP4 : CONTROLLER OUTPUT [...
# 1070  Air Knife TP4 : SETPOINT TO CONTROLLER [0..500...
# 1324                           Zero line TP4+5 [0..2 m]
# 1325  Zero line TP4-5 : SETPOINT TO CONTROLLER [-50....
# 1424  Prorelease TP4 : SETPOINT TO CONTROLLER [-5000...
